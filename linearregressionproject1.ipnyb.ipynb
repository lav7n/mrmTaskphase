# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\User\Downloads\CarPrices\CarPrice_Assignment.csv")
test = pd.read_csv(r"C:\Users\User\Downloads\CarPrices\CarPrice_Assignment.csv")
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
#Finding Co-relation
data.corr()
# Out:
#                     car_ID  symboling  wheelbase  carlength  carwidth  \
# car_ID            1.000000  -0.151621   0.129729   0.170636  0.052387
# symboling        -0.151621   1.000000  -0.531954  -0.357612 -0.232919
# wheelbase         0.129729  -0.531954   1.000000   0.874587  0.795144
# carlength         0.170636  -0.357612   0.874587   1.000000  0.841118
# carwidth          0.052387  -0.232919   0.795144   0.841118  1.000000
# carheight         0.255960  -0.541038   0.589435   0.491029  0.279210
# curbweight        0.071962  -0.227691   0.776386   0.877728  0.867032
# enginesize       -0.033930  -0.105790   0.569329   0.683360  0.735433
# boreratio         0.260064  -0.130051   0.488750   0.606454  0.559150
# stroke           -0.160824  -0.008735   0.160959   0.129533  0.182942
# compressionratio  0.150276  -0.178515   0.249786   0.158414  0.181129
# horsepower       -0.015006   0.070873   0.353294   0.552623  0.640732
# ...

# %%
#Parameters with + corelation to price: Horsepower, enginesize, curbweight, carwidth,carlength
horsepower = data.horsepower
enginesize = data.enginesize
curbweight = data.curbweight
carwidth = data.carwidth
carlength = data.carlength
price = data.price
plt.scatter(enginesize, price)
 #Checking chosen parameter for trends

# %%
plt.scatter(horsepower, price)

# %%
plt.scatter(curbweight, price)

# %%
plt.scatter(carwidth, price)

# %%
plt.scatter(carlength, price)

# %%
#Building the model
#n_iters are iterations, lr learning rate

class LinearRegression:

    def __init__(self, lr=0.001, n_iters=2000):
        self.lr=lr
        self.n_iters= n_iters
        self.weights= None
        self.base= None

    def fit(self, X, y):
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias=0

        for i in range(self.n_iters):   
          y_pred = np.dot(X, self.weights) + self.bias
          #Hypothesis function y = mx + c, where x is weights and c is bias

          dw = (1/n_samples) * np.dot(X.T, (y_pred - y))
          db = (1/n_samples) * np.sum(y_pred-y)
          #Trains the weights and biases to new values with each iteration

          self.weights = self.weights - self.lr * dw
          self.bias = self.bias - self.lr * db   
          

    def predict(self, X):
        y_pred = np.dot(X,self.weights) + self.bias
        return y_pred

# %%
#Creating Test dataset
test
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
test = test.drop(['price'],axis=1)
test.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  cylindernumber  \
# 0  convertible        rwd          front       88.6  ...            four
# 1  convertible        rwd          front       88.6  ...            four
# 2    hatchback        rwd          front       94.5  ...             six
# 3        sedan        fwd          front       99.8  ...            four
# 4        sedan        4wd          front       99.4  ...            five
#
# ...

# %%
car_ID	= data.car_ID
symboling	= data.symboling
CarName	= data.CarName
fueltype = data.fueltype
aspiration = data.aspiration
doornumber	= data.doornumber
carbody = data.carbody
drivewheel = data.drivewheel
enginelocation = data.enginelocation
wheelbase = data.wheelbase
carheight = data.carheight
enginetype = data.enginetype
cylindernumber = data.cylindernumber
fuelsystem = data.fuelsystem
boreratio = data.fuelsystem
stroke = data.stroke
compressionratio = data.compressionratio
peakrpm = data.peakrpm
citympg = data.citympg
highwaympg = data.highwaympg

# %%
#Since we have already selected parameters to test on, we will drop the columns which are not needed.
#Parameters with + corelation to price: Horsepower, enginesize, curbweight, carwidth,carlength
test = test.drop(["car_ID"], axis=1)

# %%
test.head()
# Out:
#    symboling                   CarName fueltype aspiration doornumber  \
# 0          3        alfa-romero giulia      gas        std        two
# 1          3       alfa-romero stelvio      gas        std        two
# 2          1  alfa-romero Quadrifoglio      gas        std        two
# 3          2               audi 100 ls      gas        std       four
# 4          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0  convertible        rwd          front       88.6      168.8  ...
# 1  convertible        rwd          front       88.6      168.8  ...
# 2    hatchback        rwd          front       94.5      171.2  ...
# 3        sedan        fwd          front       99.8      176.6  ...
# 4        sedan        4wd          front       99.4      176.6  ...
#
#    cylindernumber  enginesize  fuelsystem boreratio stroke  compressionratio  \
# ...

# %%
test = test.drop(["symboling"],axis=1)

# %%
test = test.drop(["CarName"],axis=1)

# %%
test = test.drop(["fueltype"],axis=1)

# %%
test = test.drop(["symboling"],axis=1)

# %%
test = test.drop(["aspiration"],axis=1)

# %%
test = test.drop(["highwaympg"],axis=1)

# %%
test = test.drop(["citympg"],axis=1)

# %%
test = test.drop(["doornumber"],axis=1)

# %%
test = test.drop(["carbody"],axis=1)

# %%
test = test.drop(["drivewheel"],axis=1)

# %%
test = test.drop(["wheelbase"],axis=1)

# %%
test = test.drop(["carheight"],axis=1)

# %%
test = test.drop(["enginetype"],axis=1)

# %%
test = test.drop(["cylindernumber"],axis=1)

# %%
test = test.drop(["compressionratio"],axis=1)

# %%
test = test.drop(["stroke"],axis=1)

# %%
test = test.drop(["peakrpm"],axis=1)

# %%
test = test.drop(["boreratio"],axis=1)

# %%
test = test.drop(["fuelsystem"],axis=1)

# %%
test = test.drop(["enginelocation"], axis=1)

# %%
test.head()
# Out:
#    carlength  carwidth  curbweight  enginesize  horsepower
# 0      168.8      64.1        2548         130         111
# 1      168.8      64.1        2548         130         111
# 2      171.2      65.5        2823         152         154
# 3      176.6      66.2        2337         109         102
# 4      176.6      66.4        2824         136         115

# %%
test.dtypes
# Out:
# carlength     float64
# carwidth      float64
# curbweight      int64
# enginesize      int64
# horsepower      int64
# dtype: object

# %%
X_train, y_train = test.iloc[:,:11].values, test.iloc[:,-1].values
X_train.shape, y_train.shape
# Out:
# ((205, 5), (205,))

# %%
X_test, y_test = test.iloc[:,:11].values, test.iloc[:,-1].values
X_test.shape, y_test.shape
print(X_train)
y_train
X_test
# Out:
# [[ 168.8   64.1 2548.   130.   111. ]
#  [ 168.8   64.1 2548.   130.   111. ]
#  [ 171.2   65.5 2823.   152.   154. ]
#  ...
#  [ 188.8   68.9 3012.   173.   134. ]
#  [ 188.8   68.9 3217.   145.   106. ]
#  [ 188.8   68.9 3062.   141.   114. ]]
# array([[ 168.8,   64.1, 2548. ,  130. ,  111. ],
#        [ 168.8,   64.1, 2548. ,  130. ,  111. ],
#        [ 171.2,   65.5, 2823. ,  152. ,  154. ],
#        ...,
#        [ 188.8,   68.9, 3012. ,  173. ,  134. ],
#        [ 188.8,   68.9, 3217. ,  145. ,  106. ],
#        [ 188.8,   68.9, 3062. ,  141. ,  114. ]])

# %%
#Feature Scaling
X_train = (X_train - X_train.mean(axis = 0)) / ( X_train.max(axis = 0) - X_train.min(axis = 0) )
X_test = (X_test - X_test.mean(axis = 0)) / ( X_test.max(axis = 0) - X_test.min(axis = 0) )
X_train
X_test
# Out:
# array([[-0.07834729, -0.15065041, -0.00293478,  0.0116705 ,  0.02867886],
#        [-0.07834729, -0.15065041, -0.00293478,  0.0116705 ,  0.02867886],
#        [-0.04252639, -0.03398374,  0.10373706,  0.09468937,  0.20784553],
#        ...,
#        [ 0.22016017,  0.24934959,  0.17704971,  0.17393465,  0.1245122 ],
#        [ 0.22016017,  0.24934959,  0.25656871,  0.06827428,  0.00784553],
#        [ 0.22016017,  0.24934959,  0.19644459,  0.05317994,  0.04117886]])

# %%
fig = plt.figure()
plt.scatter(X_train[:, 4],y_train, color = "b", marker = "X", s = 30)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Feeding the sets into the model

reg = LinearRegression(lr=0.001, n_iters= 50000)
reg.fit(X_train,y_train)
predictions = reg.predict(X_test)

# %%
print(predictions)
# Out:
# [105.46063248 105.46063248 135.83123722  97.04899546 115.45374239
#  108.41401618 119.98471521 121.55051536 136.80617471 141.26526145
#   95.30578485  95.30578485 119.70046739 120.48336746 127.33790112
#  167.24925558 170.69357111 176.52003113  42.6779898   68.36568997
#   68.83289471  67.69774328  67.69774328  88.97720383  68.99308704
#   69.30624706  69.30624706  89.87398028  93.44590644 133.17757971
#   61.25219387  71.34290122  61.64054999  73.14359416  73.37134691
#   73.99675072  74.12734365  86.90511305  87.65954403  87.78860196
#   85.08333306  97.23190182  95.46250589  80.05417842  68.36568997
#   68.86389911  97.51394678 188.92710268 188.92710268 242.32167693
#   68.60723857  68.74958404  68.82075678  69.30781661  69.37898935
#   89.35960262  89.35960262  89.43077535 109.13065359  91.95429309
#   92.31015676  91.95429309  92.31015676  83.24451303  92.52367496
#  115.99553984  92.42600344 142.96478229 146.30990078 142.71644134
# ...

# %%
#Finding meansquare error
def mse(y_test, predictions):
    return np.mean((y_test-predictions)**2)

# %%
mse = mse(y_test, predictions)
print(mse)
# Out:
# 151.3546427236918

# %%
r2 = 1 - ( (np.sum(np.square(y_test - predictions))) / (np.sum( np.square(y_test - y_test.mean()) )) )
r2
# Out:
# 0.9027354499663977

# %% [markdown]
# Therefore, the model works with 90% accuracy using 5 parameters.
